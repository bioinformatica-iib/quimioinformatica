# %%
# !pip install rdkit

# %%
from rdkit import DataStructs
from rdkit import Chem
from rdkit.Chem.Fingerprints import FingerprintMols
from rdkit.Chem import Draw
ms = [
    Chem.MolFromSmiles('C1=CC=C(C=C1)C1=CC(=CC(=C1)C1=CC=CC=C1)C1=CC=CC=C1'),
    Chem.MolFromSmiles('C1=NC(=NC=N1)C1=NC(=NC(=N1)C1=NC=NC=N1)C1=NC=NC=N1'),
    Chem.MolFromSmiles('S1C=CC=C1'),
    Chem.MolFromSmiles('C1=CC=CC=C1')
    ]
fps = [FingerprintMols.FingerprintMol(x) for x in ms]
print(ms[0], ms[1], DataStructs.FingerprintSimilarity(fps[0],fps[1]))

# %%
# biphenyl = Chem.MolFromSmiles('C1=CC=C(C=C1)C1=CC=CC=C1') # is the query

database = [
    Chem.MolFromSmiles('C1=CC=C(C=C1)C1=CC=CC=C1'),
    Chem.MolFromSmiles('C1=CC=C(C=C1)C1=CC=C(C=C1)C1=CC=CC=C1'),
    Chem.MolFromSmiles('C1=CC=C(C=C1)C1=CC=C(C=C1)C1=CC=C(C=C1)C1=CC=CC=C1'),
    Chem.MolFromSmiles('C1=CC=C(C=C1)C1=CC=C(C=C1)C1=CC=C(C=C1)C1=CC=C(C=C1)C1=CC=CC=C1'),
    Chem.MolFromSmiles('C1=CC=C(C=C1)C1=CC=C(C=C1)C1=CC=C(C=C1)C1=CC=C(C=C1)C1=CC=C(C=C1)C1=CC=CC=C1'),
    Chem.MolFromSmiles('C1=CC=C(C=C1)C1=CC=C(C=C1)C1=CC=C(C=C1)C1=CC=C(C=C1)C1=CC=C(C=C1)C1=CC=C(C=C1)C1=CC=CC=C1'),
    ]

# %%
Draw.MolsToGridImage(database)

# %%
from rdkit import DataStructs
from rdkit import Chem
from rdkit.Chem.Fingerprints import FingerprintMols

fps = [FingerprintMols.FingerprintMol(x) for x in database]
print("biphenyl vs itself:", DataStructs.FingerprintSimilarity(fps[0],fps[0]))
print("biphenyl vs 3-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[1]))
print("biphenyl vs 4-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[2]))
print("biphenyl vs 5-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[3]))
print("biphenyl vs 6-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[4]))
print("biphenyl vs 7-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[5]))

# %%
from rdkit import DataStructs
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem.Fingerprints import FingerprintMols

# obtenemos nuestro generador de fingerprints Morgan
fpgen = AllChem.GetMorganGenerator(radius=2) # ECFP4 (radius 2 = diameter 4)

# calculamos el fingerprint
fps = [fpgen.GetFingerprint(x) for x in database]

print("biphenyl vs itself:", DataStructs.FingerprintSimilarity(fps[0],fps[0]))
print("biphenyl vs 3-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[1]))
print("biphenyl vs 4-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[2]))
print("biphenyl vs 5-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[3]))
print("biphenyl vs 6-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[4]))
print("biphenyl vs 7-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[5]))

# %%
# obtenemos nuestro generador de fingerprints Morgan
fpgen = AllChem.GetMorganGenerator(radius=3, fpSize=4096) # ECFP6 (radius 3 = diameter 6)

# calculamos el fingerprint
fps = [fpgen.GetFingerprint(x) for x in database]

print("biphenyl vs itself:", DataStructs.FingerprintSimilarity(fps[0],fps[0]))
print("biphenyl vs 3-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[1]))
print("biphenyl vs 4-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[2]))
print("biphenyl vs 5-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[3]))
print("biphenyl vs 5-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[4]))
print("biphenyl vs 5-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[5]))

print(fpgen.GetInfoString())

# %%
# obtenemos nuestro generador de fingerprints Morgan
fpgen = AllChem.GetMorganGenerator(radius=4) # ECFP8 (radius 4 = diameter 8)

# calculamos el fingerprint
fps = [fpgen.GetFingerprint(x) for x in database]

print("biphenyl vs itself:", DataStructs.FingerprintSimilarity(fps[0],fps[0]))
print("biphenyl vs 3-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[1]))
print("biphenyl vs 4-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[2]))
print("biphenyl vs 5-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[3]))
print("biphenyl vs 5-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[4]))
print("biphenyl vs 5-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[5]))

# %%
# obtenemos nuestro generador de fingerprints Morgan
fpgen = AllChem.GetMorganGenerator(radius=5) # ECFP10 (radius 5 = diameter 10)

# calculamos el fingerprint
fps = [fpgen.GetFingerprint(x) for x in database]

print("biphenyl vs itself:", DataStructs.FingerprintSimilarity(fps[0],fps[0]))
print("biphenyl vs 3-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[1]))
print("biphenyl vs 4-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[2]))
print("biphenyl vs 5-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[3]))
print("biphenyl vs 5-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[4]))
print("biphenyl vs 5-phenyl:", DataStructs.FingerprintSimilarity(fps[0],fps[5]))

# %% [markdown]
# ## Flower 1998
#
# Flower, D. R. (1998). On the Properties of Bit String-Based Measures of Chemical Similarity. Journal of Chemical Information and Computer Sciences, 38(3), 379–386. doi:10.1021/ci970437z
#
# Paper interesante (pero viejo!). Los fingerprints evolucionaron bastante desde entonces!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
databasea = [
    Chem.MolFromSmiles("OC(O)C1=CSC(NC(=O)C2=CN=CC(Cl)=C2)=N1"), # query
    Chem.MolFromSmiles("NC(=S)C1=CC=C(NC(=S)CC2=CC(Br)=CO2)O1"), # I
    Chem.MolFromSmiles("C(C1CCCCN1CC1=CC=C2C=CC=CC2=C1)C1=CC=CC=C1"), # II
    Chem.MolFromSmiles("CCCCCCCCCCC#CC1=C(CCC(O)=O)C=CC=C1") # III
]

# %%
Draw.MolsToGridImage(databasea)

# %%
# fingerprints MACCS | old (similar to UNITY used in Flower DR 1998)
fps = [Chem.rdMolDescriptors.GetMACCSKeysFingerprint(x) for x in databasea]

print("query vs itself:", DataStructs.FingerprintSimilarity(fps[0],fps[0]))
print("query vs I:", DataStructs.FingerprintSimilarity(fps[0],fps[1]))
print("query vs II:", DataStructs.FingerprintSimilarity(fps[0],fps[2]))
print("query vs III:", DataStructs.FingerprintSimilarity(fps[0],fps[3]))

# %%
# obtenemos nuestro generador de fingerprints Morgan
fpgen = AllChem.GetMorganGenerator(radius=2, fpSize=512) # ECFP4 (radius 2 = diameter 4)

# calculamos el fingerprint
fps = [fpgen.GetFingerprint(x) for x in databasea]

print("query vs itself:", DataStructs.FingerprintSimilarity(fps[0],fps[0]))
print("query vs I:", DataStructs.FingerprintSimilarity(fps[0],fps[1]))
print("query vs II:", DataStructs.FingerprintSimilarity(fps[0],fps[2]))
print("query vs III:", DataStructs.FingerprintSimilarity(fps[0],fps[3]))

# %%
# obtenemos nuestro generador de fingerprints Morgan
fpgen = AllChem.GetMorganGenerator(radius=3, fpSize=512) # ECFP6 (radius 3 = diameter 6)

# calculamos el fingerprint
fps = [fpgen.GetFingerprint(x) for x in databasea]

print("query vs itself:", DataStructs.FingerprintSimilarity(fps[0],fps[0]))
print("query vs I:", DataStructs.FingerprintSimilarity(fps[0],fps[1]))
print("query vs II:", DataStructs.FingerprintSimilarity(fps[0],fps[2]))
print("query vs III:", DataStructs.FingerprintSimilarity(fps[0],fps[3]))

# %%
databaseb = [
    Chem.MolFromSmiles("OC(O)C1=CSC(NC(=O)C2=CN=CC(Cl)=C2)=N1"), # query
    Chem.MolFromSmiles("CC(=O)NC1=NC(=CS1)C(C)=O"), # I
    Chem.MolFromSmiles("COC1=CC2=C(C=C1)N(CC1=CC=CC=C1)CC2C(=O)CNC1=NC(C)=CS1"), # II
    Chem.MolFromSmiles("CC1=CC=C(C=C1)C12CC3CCC(C1)C(C3C2)C1=CSC(NC(=O)C2=CC(=CC=C2Cl)[N+]([O-])=O)=N1"), # III
]

# %%
Draw.MolsToGridImage(databaseb)

# %%
# fingerprints MACCS | old (similar to UNITY used in Flower DR 1998)
fps = [Chem.rdMolDescriptors.GetMACCSKeysFingerprint(x) for x in databaseb]

print("query vs itself:", DataStructs.FingerprintSimilarity(fps[0],fps[0]))
print("query vs I:", DataStructs.FingerprintSimilarity(fps[0],fps[1]))
print("query vs II:", DataStructs.FingerprintSimilarity(fps[0],fps[2]))
print("query vs III:", DataStructs.FingerprintSimilarity(fps[0],fps[3]))

# %%
# obtenemos nuestro generador de fingerprints Morgan
fpgen = AllChem.GetMorganGenerator(radius=3, fpSize=2048) # ECFP6 (radius 3 = diameter 6)

# calculamos el fingerprint
fps = [fpgen.GetFingerprint(x) for x in databasea]

print("query vs itself:", DataStructs.FingerprintSimilarity(fps[0],fps[0]))
print("query vs I:", DataStructs.FingerprintSimilarity(fps[0],fps[1]))
print("query vs II:", DataStructs.FingerprintSimilarity(fps[0],fps[2]))
print("query vs III:", DataStructs.FingerprintSimilarity(fps[0],fps[3]))
